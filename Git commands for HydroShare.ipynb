# %% [markdown]
# # List of git commands for Hydroshare:
#
# A live document of my experience with git and Hydroshare.
# Derived from https://www.linux.com/learn/beginning-git-and-github-linux-users
#
# Main point:
#
# Start a project in git and then clone it to Hydroshare

# %% [markdown]
# ## Cloning a git repository

# %% [raw]
# 1) Create a dummy git repository in github or use one existing

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2) In terminal create a git repo folder if there is none previous and navigate to it

# %% [raw]
# mkdir git-repos
#
# cd git-repos

# %% [markdown]
# 3) In terminal clone the repository (in this case playground) using its git address

# %% [raw]
# git clone https://github.com/torresrua/playground.git

# %% [markdown]
# 4) and see the files in the local repository

# %% [raw]
# ls playground/

# %% [markdown]
# ## adding files to git
# When new files were added to the cloned repo, we need to tell git to track them. So navigate to the local repo folder and:

# %% [raw]
# git add *

# %% [markdown]
# ## removing files from git
# When files are deleted in the cloned repo, we need to tell git to un-tack them. So navigate to the local repo folder and:

# %% [raw]
# git add -u

# %% [markdown]
# ## committing and pushing files to Github
# all of them

# %% [raw]
# git commit -a

# %% [markdown]
# then

# %% [raw]
# git push origin master
